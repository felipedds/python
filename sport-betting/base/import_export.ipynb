# %% [markdown]
# <h5>Import dataset - Main leagues</h5>
# <h6>Load the dataset from a file .csv<br>
# Font: https://www.football-data.co.uk/data.php<h6>

# %%
import numpy as np
import pandas as pd

pd.set_option('display.min_rows', 200)
pd.set_option("display.max_rows", 600)
pd.set_option("display.max_columns", 100)

# ENGLAND
# Premier League - England
premier_league_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E0.csv")
premier_league_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E0.csv")
premier_league_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E0.csv")
premier_league_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E0.csv")
premier_league_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E0.csv")
premier_league_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E0.csv")
premier_league_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv")
premier_league_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")
premier_league = pd.concat([premier_league_2015_2016, premier_league_2016_2017, premier_league_2017_2018, premier_league_2018_2019, premier_league_2019_2020, premier_league_2020_2021, premier_league_2021_2022, premier_league_2022_2023], axis=0, ignore_index=True)
premier_league["League"] = "Premier League"
premier_league = premier_league[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
premier_league.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
premier_league = premier_league.astype({"date":"datetime64"})
premier_league = premier_league.convert_dtypes(infer_objects=True)

# EFL Championship - England
efl_championship_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E1.csv")
efl_championship_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E1.csv")
efl_championship_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E1.csv")
efl_championship_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E1.csv")
efl_championship_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E1.csv")
efl_championship_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E1.csv")
efl_championship_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E1.csv")
efl_championship_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E1.csv")
efl_championship = pd.concat([efl_championship_2015_2016, efl_championship_2016_2017, efl_championship_2017_2018, efl_championship_2018_2019, efl_championship_2019_2020, efl_championship_2020_2021, efl_championship_2021_2022, efl_championship_2022_2023], axis=0, ignore_index=True)
efl_championship["League"] = "EFL Championship"
efl_championship = efl_championship[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
efl_championship.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
efl_championship = efl_championship.astype({"date":"datetime64"})
efl_championship = efl_championship.convert_dtypes(infer_objects=True)

# SCOTLAND
# Scottish Premiership - Scotland
scottish_premiership_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SC0.csv")
scottish_premiership_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SC0.csv")
scottish_premiership_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SC0.csv")
scottish_premiership_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SC0.csv")
scottish_premiership = pd.concat([scottish_premiership_2019_2020, scottish_premiership_2020_2021, scottish_premiership_2021_2022, scottish_premiership_2022_2023], axis=0, ignore_index=True)
scottish_premiership["League"] = "Scottish Premiership"
scottish_premiership = scottish_premiership[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
scottish_premiership.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
scottish_premiership = scottish_premiership.astype({"date":"datetime64"})
scottish_premiership = scottish_premiership.convert_dtypes(infer_objects=True)

# GERMANY
# 1. Bundesliga - Germany
bundesliga_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D1.csv")
bundesliga_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D1.csv")
bundesliga_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D1.csv")
bundesliga_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D1.csv")
bundesliga_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D1.csv")
bundesliga_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D1.csv")
bundesliga_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D1.csv")
bundesliga_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/D1.csv")
bundesliga = pd.concat([bundesliga_2015_2016, bundesliga_2016_2017, bundesliga_2017_2018, bundesliga_2018_2019, bundesliga_2019_2020, bundesliga_2020_2021, bundesliga_2021_2022, bundesliga_2022_2023], axis=0, ignore_index=True)
bundesliga["League"] = "Bundesliga"
bundesliga = bundesliga[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
bundesliga.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
bundesliga = bundesliga.astype({"date":"datetime64"})
bundesliga = bundesliga.convert_dtypes(infer_objects=True)

# ITALY
# Serie A - Italy
seriea_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I1.csv")
seriea_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I1.csv")
seriea_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I1.csv")
seriea_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I1.csv")
seriea_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I1.csv")
seriea_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I1.csv")
seriea_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I1.csv")
seriea_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I1.csv")
seriea = pd.concat([seriea_2015_2016, seriea_2016_2017, seriea_2017_2018, seriea_2018_2019, seriea_2019_2020, seriea_2020_2021, seriea_2021_2022, seriea_2022_2023], axis=0, ignore_index=True)
seriea["League"] = "Serie A"
seriea = seriea[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
seriea.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
seriea = seriea.astype({"date":"datetime64"})
seriea = seriea.convert_dtypes(infer_objects=True)

# SPAIN
# LaLiga - Spain
laliga_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP1.csv")
laliga_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP1.csv")
laliga_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP1.csv")
laliga_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP1.csv")
laliga_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP1.csv")
laliga_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP1.csv")
laliga_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP1.csv")
laliga_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP1.csv")
laliga = pd.concat([laliga_2015_2016, laliga_2016_2017, laliga_2017_2018, laliga_2018_2019, laliga_2019_2020, laliga_2020_2021, laliga_2021_2022, laliga_2022_2023], axis=0, ignore_index=True)
laliga["League"] = "LaLiga"
laliga = laliga[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
laliga.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
laliga = laliga.astype({"date":"datetime64"})
laliga = laliga.convert_dtypes(infer_objects=True)

# FRANCE
# Ligue 1 - France
ligue1_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F1.csv")
ligue1_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F1.csv")
ligue1_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F1.csv")
ligue1_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F1.csv")
ligue1_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F1.csv")
ligue1_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F1.csv")
ligue1_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F1.csv")
ligue1_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F1.csv")
ligue1 = pd.concat([ligue1_2015_2016, ligue1_2016_2017, ligue1_2017_2018, ligue1_2018_2019, ligue1_2019_2020, ligue1_2020_2021, ligue1_2021_2022, ligue1_2022_2023], axis=0, ignore_index=True)
ligue1["League"] = "LaLiga"
ligue1 = ligue1[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
ligue1.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
ligue1 = ligue1.astype({"date":"datetime64"})
ligue1 = ligue1.convert_dtypes(infer_objects=True)

# NETHERLANDS
# Eredivisie - Netherlands
eredivisie_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/N1.csv")
eredivisie_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/N1.csv")
eredivisie_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/N1.csv")
eredivisie_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/N1.csv")
eredivisie_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/N1.csv")
eredivisie_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/N1.csv")
eredivisie_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/N1.csv")
eredivisie_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv")
eredivisie = pd.concat([eredivisie_2015_2016, eredivisie_2016_2017, eredivisie_2017_2018, eredivisie_2018_2019, eredivisie_2019_2020, eredivisie_2020_2021, eredivisie_2021_2022, eredivisie_2022_2023], axis=0, ignore_index=True)
eredivisie["League"] = "Eredivisie"
eredivisie = eredivisie[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
eredivisie.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
eredivisie = eredivisie.astype({"date":"datetime64"})
eredivisie = eredivisie.convert_dtypes(infer_objects=True)

# PORTUGAL
# Primeira Liga - Portugal
primeira_liga_2015_2016 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/N1.csv")
primeira_liga_2016_2017 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/N1.csv")
primeira_liga_2017_2018 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/N1.csv")
primeira_liga_2018_2019 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/N1.csv")
primeira_liga_2019_2020 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/N1.csv")
primeira_liga_2020_2021 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/N1.csv")
primeira_liga_2021_2022 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/N1.csv")
primeira_liga_2022_2023 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv")
primeira_liga = pd.concat([primeira_liga_2015_2016, primeira_liga_2016_2017, primeira_liga_2017_2018, primeira_liga_2018_2019, primeira_liga_2019_2020, primeira_liga_2020_2021, primeira_liga_2021_2022, primeira_liga_2022_2023], axis=0, ignore_index=True)
primeira_liga["League"] = "Eredivisie"
primeira_liga = primeira_liga[["League", "Date", "HomeTeam", "AwayTeam", "HTHG", "HTAG", "HTR", "FTHG", "FTAG", "FTR", "B365H", "B365D", "B365A", "B365>2.5"]]
primeira_liga.columns = ["league", "date", "home", "away", "home_goals_ht", "away_goals_ht", "result_ht", "home_goals_ft", "away_goals_ft", "result_ft", "home_odds", "draw_odds", "away_odds", "morethan_2.5_goals_odds"]
primeira_liga = primeira_liga.astype({"date":"datetime64"})
primeira_liga = primeira_liga.convert_dtypes(infer_objects=True)

df_main = pd.concat([premier_league, efl_championship, scottish_premiership, bundesliga, seriea, laliga, ligue1, eredivisie, primeira_liga], axis=0, ignore_index=True)
df_main.tail()
df_main.to_csv("full_main.csv")

# %% [markdown]
# <h5>Import dataset - Extra leagues</h5>
# <h6>Load the dataset from a file .csv<br>
# Font: https://www.football-data.co.uk/data.php<h6>

# %%
# ARGENTINE
# Argentine Primera División - Argentine
argentine_primera_division = pd.read_csv("https://www.football-data.co.uk/new/ARG.csv")
argentine_primera_division["league"] = "Argentine Primera Division"

# BRAZIL
# Brasileirão Série A - Brazil
brasileirao_serie_a  = pd.read_csv("https://www.football-data.co.uk/new/BRA.csv")
brasileirao_serie_a["league"] = "Brasileirao Serie A"

# CHINA
# Chinese Super League - China
chinese_super_league   = pd.read_csv("https://www.football-data.co.uk/new/CHN.csv")
chinese_super_league["league"] = "Brasileirao Serie A"

# USA
# MLS - USA
mls  = pd.read_csv("https://www.football-data.co.uk/new/USA.csv")
mls["league"] = "MLS"

df_extra = pd.concat([argentine_primera_division, brasileirao_serie_a, mls], axis=0, ignore_index=True)
df_extra = df_extra[["League", "Date", "Home", "Away", "HG", "AG", "Res", "PH", "PD", "PA"]]
df_extra.columns = ["league", "date", "home", "away", "home_goals", "away_goals", "result", "home_odds", "draw_odds", "away_odds"]
df_extra.tail()

# Export dataset
df_extra.to_csv("full_extra.csv")
