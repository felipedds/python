# %%
import pandas as pd
import re

# Read data
data = pd.read_csv("daily_million.csv")

# Feature Engineering
data["day"] = data["day"].str.replace('\D+', '')
data
# Out:
#                           date day month  year  ball1  ball2  ball3  ball4  \
# 0     December 31st 2016 - 9pm  31   Dec  2016     19     29     31     32
# 1     December 31st 2016 - 2pm  31   Dec  2016      3     16     21     23
# 2     December 30th 2016 - 9pm  30   Dec  2016      9     10     11     17
# 3     December 30th 2016 - 2pm  30   Dec  2016      2      7     16     22
# 4     December 29th 2016 - 9pm  29   Dec  2016     11     16     18     28
# ...                        ...  ..   ...   ...    ...    ...    ...    ...
# 4520    January 3rd 2023 - 2pm   3   Jan  2023      1     16     25     33
# 4521    January 2nd 2023 - 9pm   2   Jan  2023      9     15     20     23
# 4522    January 2nd 2023 - 2pm   2   Jan  2023      7     18     25     27
# 4523    January 1st 2023 - 9pm   1   Jan  2023      4      8     11     15
# 4524    January 1st 2023 - 2pm   1   Jan  2023      4      6      9     11
#
#       ball5  ball6  bonus
# 0        35     39     33
# ...

# %%
data
# Out:
#                           date day month  year  ball1  ball2  ball3  ball4  \
# 0     December 31st 2016 - 9pm  31   Dec  2016     19     29     31     32
# 1     December 31st 2016 - 2pm  31   Dec  2016      3     16     21     23
# 2     December 30th 2016 - 9pm  30   Dec  2016      9     10     11     17
# 3     December 30th 2016 - 2pm  30   Dec  2016      2      7     16     22
# 4     December 29th 2016 - 9pm  29   Dec  2016     11     16     18     28
# ...                        ...  ..   ...   ...    ...    ...    ...    ...
# 4520    January 3rd 2023 - 2pm   3   Jan  2023      1     16     25     33
# 4521    January 2nd 2023 - 9pm   2   Jan  2023      9     15     20     23
# 4522    January 2nd 2023 - 2pm   2   Jan  2023      7     18     25     27
# 4523    January 1st 2023 - 9pm   1   Jan  2023      4      8     11     15
# 4524    January 1st 2023 - 2pm   1   Jan  2023      4      6      9     11
#
#       ball5  ball6  bonus
# 0        35     39     33
# ...
